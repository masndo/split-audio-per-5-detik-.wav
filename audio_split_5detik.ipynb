# %% [markdown]
# <a href="https://colab.research.google.com/github/masndo/split-audio-per-5-detik-.wav/blob/main/audio_split_5detik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

input_folder = "/content/drive/MyDrive/dataset_rvc"   # folder audio asli
output_folder = "/content/drive/MyDrive/dataset_rvc_chunks"  # hasil potongan

os.makedirs(output_folder, exist_ok=True)

# %%
# !pip install pydub

from pydub import AudioSegment
from tqdm import tqdm

# %%
chunk_length_ms = 5000  # 5 detik

for file_name in tqdm(os.listdir(input_folder)):
    if file_name.endswith((".wav", ".mp3", ".flac")):
        file_path = os.path.join(input_folder, file_name)

        audio = AudioSegment.from_file(file_path)
        duration = len(audio)

        for i in range(0, duration, chunk_length_ms):
            chunk = audio[i:i+chunk_length_ms]

            chunk_name = f"{os.path.splitext(file_name)[0]}_chunk_{i//1000}.wav"
            chunk.export(os.path.join(output_folder, chunk_name), format="wav")
